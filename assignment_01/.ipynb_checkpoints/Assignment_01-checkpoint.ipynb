# %%
import pandas as pd
dataset = pd.read_csv("dataset.csv")

# %%
dataset
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
dataset.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course math score  reading score  writing score
# 0                    none         72           72.0           74.0
# 1               completed         69           90.0           88.0
# 2                    none         90           95.0           93.0
# 3                    none         47           57.0           44.0
# 4                    none         76           78.0           75.0

# %%
dataset.head
# Out:
# <bound method NDFrame.head of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# ...

# %%
dataset.shape
# Out:
# (1000, 8)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   992 non-null    object
#  6   reading score                994 non-null    float64
#  7   writing score                991 non-null    float64
# dtypes: float64(2), object(6)
# memory usage: 62.6+ KB

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# ...

# %%
dataset.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
dataset.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
dataset.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     8
# reading score                  6
# writing score                  9
# dtype: int64

# %%
dataset['math score'].unique()
# Out:
# array(['72', '69', '90', '47', '76', '71', '88', '40', '64', '38', '58',
#        '65', '78', '50', nan, '74', '73', '67', '70', '62', '63', '56',
#        '81', '75', '57', '55', '53', '59', '66', '82', '77', '33', '52',
#        '0', '79', '39', '45', '60', '61', '41', '49', '44', '30', '80',
#        '42', '27', '43', '68', '85', '98', '87', '54', '51', '99', '84',
#        '91', '83', '89', '22', '100', '96', '94', '46', '97', '48', '35',
#        '34', '86', '92', '37', '28', '24', '113', '123', '?', '-89', '26',
#        '334', '95', '36', '29', '32', '93', '19', '23', '8'], dtype=object)

# %%
dataset_copy = dataset.copy()

# %%
dataset_copy
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
dataset_copy['math score'] = dataset_copy['math score'].astype('str')

# %%
dataset_copy.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
dataset_copy['math score'].unique()
# Out:
# array(['72', '69', '90', '47', '76', '71', '88', '40', '64', '38', '58',
#        '65', '78', '50', 'nan', '74', '73', '67', '70', '62', '63', '56',
#        '81', '75', '57', '55', '53', '59', '66', '82', '77', '33', '52',
#        '0', '79', '39', '45', '60', '61', '41', '49', '44', '30', '80',
#        '42', '27', '43', '68', '85', '98', '87', '54', '51', '99', '84',
#        '91', '83', '89', '22', '100', '96', '94', '46', '97', '48', '35',
#        '34', '86', '92', '37', '28', '24', '113', '123', '?', '-89', '26',
#        '334', '95', '36', '29', '32', '93', '19', '23', '8'], dtype=object)

# %%
len(dataset_copy['math score'].unique())
# Out:
# 86

# %%
dataset['math score'].unique()
# Out:
# array(['72', '69', '90', '47', '76', '71', '88', '40', '64', '38', '58',
#        '65', '78', '50', nan, '74', '73', '67', '70', '62', '63', '56',
#        '81', '75', '57', '55', '53', '59', '66', '82', '77', '33', '52',
#        '0', '79', '39', '45', '60', '61', '41', '49', '44', '30', '80',
#        '42', '27', '43', '68', '85', '98', '87', '54', '51', '99', '84',
#        '91', '83', '89', '22', '100', '96', '94', '46', '97', '48', '35',
#        '34', '86', '92', '37', '28', '24', '113', '123', '?', '-89', '26',
#        '334', '95', '36', '29', '32', '93', '19', '23', '8'], dtype=object)

# %%
mask = dataset_copy['math score'] == '?'

print(mask)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool

# %%
for i in mask:
    print(i)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
dataset_copy[~mask]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
dataset_copy[mask]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 432    male        group C                 high school      standard
# 433  female        group A            some high school  free/reduced
# 434    male        group C            some high school      standard
# 435    male        group C                some college  free/reduced
# 436    male        group D          associate's degree      standard
# 437    male        group D          associate's degree  free/reduced
# 438    male        group C                 high school      standard
# 439    male        group D            some high school      standard
# 440  female        group C                some college      standard
# 441  female        group D                 high school      standard
# 442  female        group A            some high school  free/reduced
# 443  female        group B          associate's degree      standard
# 444    male        group A            some high school  free/reduced
# ...

# %%
dataset_copy = dataset_copy[~mask]

# %%
dataset_copy
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score
# 0                      none         72           72.0           74.0
# ...

# %%
dataset_copy['math score'].unique()
# Out:
# array(['72', '69', '90', '47', '76', '71', '88', '40', '64', '38', '58',
#        '65', '78', '50', 'nan', '74', '73', '67', '70', '62', '63', '56',
#        '81', '75', '57', '55', '53', '59', '66', '82', '77', '33', '52',
#        '0', '79', '39', '45', '60', '61', '41', '49', '44', '30', '80',
#        '42', '27', '43', '68', '85', '98', '87', '54', '51', '99', '84',
#        '91', '83', '89', '22', '100', '96', '94', '46', '97', '48', '35',
#        '34', '86', '92', '37', '28', '24', '113', '123', '-89', '26',
#        '334', '95', '36', '29', '32', '93', '19', '23', '8'], dtype=object)

# %%
len(dataset_copy['math score'].unique())
# Out:
# 85

# %%
import numpy as np

# %%
# check if the data frame has nan value
value_to_check = 'nan'
value_present = (dataset_copy==value_to_check).any().any()
# first any is for any column and then next any is for any row

# %%
if value_present:
    print("nan value is present in the dataset")
# Out:
# nan value is present in the dataset

# %%
# now replacing all the values in the dataset that are nan to numpy's nan which stands for not a number

# %%
pd.options.mode.copy_on_write = True
dataset_copy.replace('nan',np.nan,inplace=True)

# %%
dataset_copy.isna()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
dataset_copy.isna().any()
# Out:
# gender                         False
# race/ethnicity                 False
# parental level of education    False
# lunch                          False
# test preparation course        False
# math score                      True
# reading score                   True
# writing score                   True
# dtype: bool

# %%
value_to_check = 'nan'
value_present = (dataset_copy==value_to_check).any().any()
if value_present:
    print("We have not removed nan")
else:
    print("we have removed")
# Out:
# we have removed

# %%
# we will replace na values with mean values or we can drop the nan values by using dropna function
mean_reading_score = pd.to_numeric(dataset_copy['reading score']).mean()
mean_math_score = pd.to_numeric(dataset_copy['math score']).mean()
mean_writing_score = pd.to_numeric(dataset_copy['writing score']).mean()

# %%
print(mean_reading_score, mean_math_score, mean_writing_score)
# Out:
# 68.01251303441084 66.3239289446186 69.60774058577405

# %%
dataset_copy.fillna({'math score': mean_math_score}, inplace=True)
# try to use dataset_copy['math score'].fillna(mean_math_score,inplace = True) first and if that doesn't work then use this

# %%
dataset_copy.isnull().any()
# Out:
# gender                         False
# race/ethnicity                 False
# parental level of education    False
# lunch                          False
# test preparation course        False
# math score                     False
# reading score                   True
# writing score                   True
# dtype: bool

# %%
# check the original value that must be still same
dataset.isnull().any()
# Out:
# gender                         False
# race/ethnicity                 False
# parental level of education    False
# lunch                          False
# test preparation course        False
# math score                      True
# reading score                   True
# writing score                   True
# dtype: bool

# %%
dataset_copy.fillna({'reading score':mean_reading_score},inplace = True)

# %%
dataset_copy.fillna({'writing score':mean_writing_score},inplace = True)

# %%
dataset_copy.isnull().any()
# Out:
# gender                         False
# race/ethnicity                 False
# parental level of education    False
# lunch                          False
# test preparation course        False
# math score                     False
# reading score                  False
# writing score                  False
# dtype: bool

# %%
dataset_copy.isna()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
dataset_copy.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     8
# reading score                  6
# writing score                  9
# dtype: int64

# %%
# now missing values have been removed and ? has also been removed using mask 
# chaning math score data type again
dataset_copy['math score'] = pd.to_numeric(dataset_copy['math score'])

# %%
dataset_copy.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
dataset.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
dataset_copy['Gender Encoded'] = label_encoder.fit_transform(dataset_copy['gender'])

# %%
dataset_copy
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
dataset_copy['lunch'].value_counts()
# Out:
# lunch
# standard        625
# free/reduced    340
# Name: count, dtype: int64

# %%
one_hot_encoded_data = pd.get_dummies(dataset_copy,columns = ['lunch'])

# %%
one_hot_encoded_data
# Out:
#      gender race/ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 3      male        group A          associate's degree
# 4      male        group C                some college
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# ...
