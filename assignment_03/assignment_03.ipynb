# %%
import pandas as pd

# %%
ds = pd.read_csv('nba.csv')

# %%
ds
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
ds.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
ds.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
ds.isna().any()
# Out:
# Name        True
# Team        True
# Number      True
# Position    True
# Age         True
# Height      True
# Weight      True
# College     True
# Salary      True
# dtype: bool

# %%
ds.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
ds.isnull().any()
# Out:
# Name        True
# Team        True
# Number      True
# Position    True
# Age         True
# Height      True
# Weight      True
# College     True
# Salary      True
# dtype: bool

# %%
ds.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
ds.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
ds['Age'].fillna(ds['Age'].mean(),inplace=True)

# %%
ds['Weight'].fillna(ds['Weight'].mean(),inplace=True)

# %%
ds['Salary'].fillna(ds['Salary'].mean(),inplace=True)

# %%
ds.dropna(inplace=True)

# %%
ds.isna().any()
# Out:
# Name        False
# Team        False
# Number      False
# Position    False
# Age         False
# Height      False
# Weight      False
# College     False
# Salary      False
# dtype: bool

# %%
ds.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
ds['Height'].value_counts()
# Out:
# Height
# 6-9     50
# 6-7     37
# 6-6     37
# 6-8     36
# 6-10    34
# 6-5     30
# 6-11    29
# 6-4     28
# 6-3     27
# 7-0     20
# 6-2     15
# 6-1     12
# 6-0     10
# 5-11     3
# 7-1      3
# 5-9      1
# 7-2      1
# Name: count, dtype: int64

# %%
height_groups = ds.groupby(ds['Height'])

# %%
height_groups

# %%
height_groups.get_group('6-11')
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 24     Chris McCullough           Brooklyn Nets     1.0       PF  21.0   6-11
# 55         Nerlens Noel      Philadelphia 76ers     4.0       PF  22.0   6-11
# 56        Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0   6-11
# 60       Christian Wood      Philadelphia 76ers    35.0       PF  20.0   6-11
# 73       Jason Thompson         Toronto Raptors     1.0       PF  29.0   6-11
# 81         Festus Ezeli   Golden State Warriors    31.0        C  26.0   6-11
# 91         Cole Aldrich    Los Angeles Clippers    45.0        C  27.0   6-11
# 98       DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0   6-11
# 113          Ryan Kelly      Los Angeles Lakers     4.0       PF  25.0   6-11
# 143    DeMarcus Cousins        Sacramento Kings    15.0        C  25.0   6-11
# 162         Joakim Noah           Chicago Bulls    13.0        C  31.0   6-11
# ...

# %%
ds.describe()
# Out:
#            Number         Age      Weight        Salary
# count  373.000000  373.000000  373.000000  3.730000e+02
# mean    16.895442   26.648794  219.627346  4.625677e+06
# std     14.974972    4.250551   25.135718  5.057520e+06
# min      0.000000   19.000000  161.000000  5.572200e+04
# 25%      5.000000   24.000000  200.000000  1.007026e+06
# 50%     12.000000   26.000000  220.000000  2.637720e+06
# 75%     25.000000   29.000000  240.000000  5.758680e+06
# max     99.000000   40.000000  279.000000  2.287500e+07

# %%
height_groups['Salary'].describe()
# Out:
#         count          mean           std         min          25%  \
# Height
# 5-11      3.0  5.891553e+05  7.926627e+05     55722.0    133733.00
# 5-9       1.0  6.912869e+06           NaN   6912869.0   6912869.00
# 6-0      10.0  5.784075e+06  6.337144e+06    947276.0   2437500.00
# 6-1      12.0  5.456567e+06  4.585905e+06    700902.0   1898610.00
# 6-10     34.0  5.111545e+06  5.162012e+06    222888.0   1044792.25
# 6-11     29.0  5.920326e+06  7.067208e+06    245177.0   1140240.00
# 6-2      15.0  2.862862e+06  2.576949e+06    525093.0    947276.00
# 6-3      27.0  5.765194e+06  5.759044e+06    189455.0   1841940.00
# 6-4      28.0  4.358526e+06  5.135309e+06    134215.0   1006902.75
# 6-5      30.0  4.379143e+06  4.235717e+06     55722.0   1159800.00
# 6-6      37.0  2.963790e+06  3.167094e+06    167406.0    947276.00
# 6-7      37.0  3.716167e+06  4.684027e+06    200600.0    981348.00
# 6-8      36.0  5.616665e+06  5.807020e+06     83397.0   1128220.00
# ...

# %%
height_groups['Weight'].describe()
# Out:
#         count        mean        std    min     25%    50%     75%    max
# Height
# 5-11      3.0  181.666667  11.547005  175.0  175.00  175.0  185.00  195.0
# 5-9       1.0  185.000000        NaN  185.0  185.00  185.0  185.00  185.0
# 6-0      10.0  183.500000  13.074572  161.0  175.00  184.0  188.75  205.0
# 6-1      12.0  183.083333  11.896969  165.0  174.50  184.5  190.25  205.0
# 6-10     34.0  243.117647  12.489425  210.0  235.50  245.0  250.75  270.0
# 6-11     29.0  244.931034  17.525351  200.0  232.00  243.0  255.00  279.0
# 6-2      15.0  185.400000   9.905266  165.0  180.00  185.0  192.50  200.0
# 6-3      27.0  192.629630   8.740481  172.0  189.00  190.0  200.00  208.0
# 6-4      28.0  204.285714  10.913319  185.0  195.00  205.0  213.50  220.0
# 6-5      30.0  203.633333  12.952122  179.0  195.00  205.0  210.00  230.0
# 6-6      37.0  211.000000  14.142136  175.0  203.00  210.0  220.00  245.0
# 6-7      37.0  220.108108  14.739938  185.0  210.00  220.0  230.00  260.0
# ...

# %%
ds.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.842684e+06
# 3      Georgia State  1.148640e+06
# 6                LSU  1.170960e+06

# %%
age_groups = ds.groupby(ds['Age'])

# %%
age_groups['Salary'].describe()
# Out:
#       count          mean           std           min           25%  \
# Age
# 19.0    2.0  1.930440e+06  2.791658e+05  1.733040e+06  1.831740e+06
# 20.0   15.0  2.616956e+06  1.609006e+06  5.250930e+05  1.515960e+06
# 21.0   14.0  2.113412e+06  1.542987e+06  5.250930e+05  1.212090e+06
# 22.0   23.0  2.465265e+06  1.582921e+06  5.250930e+05  1.145760e+06
# 23.0   34.0  2.221227e+06  2.922314e+06  8.339700e+04  6.625000e+05
# 24.0   43.0  3.994272e+06  4.865797e+06  5.250930e+05  8.961675e+05
# 25.0   42.0  3.744498e+06  4.446696e+06  5.572200e+04  9.472760e+05
# 26.0   32.0  6.902746e+06  6.322481e+06  1.342150e+05  1.070788e+06
# 27.0   36.0  6.592370e+06  6.913636e+06  5.572200e+04  1.015421e+06
# 28.0   28.0  5.277098e+06  4.423951e+06  2.061920e+05  1.602632e+06
# 29.0   18.0  6.486842e+06  5.434794e+06  1.114440e+05  1.615000e+06
# 30.0   20.0  6.415726e+06  4.733617e+06  9.472760e+05  2.683821e+06
# 31.0   17.0  7.081688e+06  6.261255e+06  9.472760e+05  3.000000e+06
# ...

# %%
# unable to create groups on age so we create it manually
bins = [19,25,31,37,43]
labels = ['19-24','25-30','31-35','36-41']
ds['AgeGroups'] = pd.cut(ds['Age'],bins=bins,labels=labels,right=False)

# %%
ds
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College        Salary AgeGroups
# ...

# %%
age_groups = ds.groupby(ds['AgeGroups'])
# Out:
# C:\Users\RITANSHU\AppData\Local\Temp\ipykernel_17340\1008588643.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_groups = ds.groupby(ds['AgeGroups'])

# %%
age_groups.get_group('19-24')
# Out:
#                 Name            Team  Number Position   Age Height  Weight  \
# 3        R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6      Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 8       Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9       Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10   Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# ..               ...             ...     ...      ...   ...    ...     ...
# 443       Trey Burke       Utah Jazz     3.0       PG  23.0    6-1   191.0
# 444       Alec Burks       Utah Jazz    10.0       SG  24.0    6-6   214.0
# 446   Derrick Favors       Utah Jazz    15.0       PF  24.0   6-10   265.0
# 449      Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 452       Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
#
#             College      Salary AgeGroups
# ...

# %%
age_groups['Salary'].describe()
# Out:
#            count          mean           std       min         25%        50%  \
# AgeGroups
# 19-24      131.0  2.875416e+06  3.376129e+06   83397.0   947276.00  1662360.0
# 25-30      176.0  5.729083e+06  5.575934e+06   55722.0  1015421.00  3566432.0
# 31-35       58.0  5.455202e+06  5.746883e+06  200600.0  1533259.25  3850156.5
# 36-41        8.0  2.997202e+06  2.180022e+06  222888.0   773144.50  3732009.5
#
#                     75%         max
# AgeGroups
# 19-24      3.173197e+06  16407501.0
# 25-30      8.622191e+06  20158622.0
# 31-35      5.728609e+06  22875000.0
# 36-41      4.882013e+06   5250000.0

# %%
weight_groups = ds.groupby(ds['Weight'])

# %%
weight_groups.describe()
# Out:
#        Number                                                         Age  \
#         count       mean        std   min    25%   50%    75%   max count
# Weight
# 161.0     1.0   0.000000        NaN   0.0   0.00   0.0   0.00   0.0   1.0
# 165.0     2.0  10.000000   2.828427   8.0   9.00  10.0  11.00  12.0   2.0
# 170.0     1.0   2.000000        NaN   2.0   2.00   2.0   2.00   2.0   1.0
# 172.0     1.0  22.000000        NaN  22.0  22.00  22.0  22.00  22.0   1.0
# 173.0     1.0   2.000000        NaN   2.0   2.00   2.0   2.00   2.0   1.0
# ...       ...        ...        ...   ...    ...   ...    ...   ...   ...
# 260.0     9.0  19.666667  14.439529   7.0  12.00  14.0  21.00  50.0   9.0
# 265.0     7.0  23.428571  12.594405   6.0  15.00  21.0  33.00  41.0   7.0
# 270.0     5.0  25.600000  16.456002  11.0  15.00  17.0  35.00  50.0   5.0
# 275.0     2.0   9.500000   2.121320   8.0   8.75   9.5  10.25  11.0   2.0
# 279.0     1.0   0.000000        NaN   0.0   0.00   0.0   0.00   0.0   1.0
# ...

# %%
bins = [160,201,241,280]
labels = ['160-200','201-240','241-280']
ds['WeightGroups'] = pd.cut(ds['Weight'],bins=bins,labels=labels,right=False)
ds
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College        Salary AgeGroups WeightGroups
# ...

# %%
weight_groups = ds.groupby(ds['WeightGroups'])

weight_groups.describe()
# Out:
# C:\Users\RITANSHU\AppData\Local\Temp\ipykernel_17340\816740503.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weight_groups = ds.groupby(ds['WeightGroups'])
#              Number                                                      \
#               count       mean        std  min   25%   50%    75%   max
# WeightGroups
# 160-200       105.0  12.742857  12.338985  0.0  3.00   9.0  21.00  55.0
# 201-240       190.0  17.505263  14.547404  0.0  5.00  13.0  26.75  99.0
# 241-280        78.0  21.000000  17.799022  0.0  7.25  15.0  32.00  90.0
#
#                 Age             ... Weight        Salary                \
#               count       mean  ...    75%    max  count          mean
# WeightGroups                    ...
# ...

# %%
# NOW ASSIGNMENT-3 PART(2)
ds = pd.read_csv("iris.csv")

# %%
ds
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
ds.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
ds.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
ds.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
ds.isna().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
ds.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
ds['Species'].describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: Species, dtype: object

# %%
specie_group = ds.groupby(ds['Species'])

# %%
specie_group.describe().transpose()
# Out:
# Species              Iris-setosa  Iris-versicolor  Iris-virginica
# Id            count    50.000000        50.000000       50.000000
#               mean     25.500000        75.500000      125.500000
#               std      14.577380        14.577380       14.577380
#               min       1.000000        51.000000      101.000000
#               25%      13.250000        63.250000      113.250000
#               50%      25.500000        75.500000      125.500000
#               75%      37.750000        87.750000      137.750000
#               max      50.000000       100.000000      150.000000
# SepalLengthCm count    50.000000        50.000000       50.000000
#               mean      5.006000         5.936000        6.588000
#               std       0.352490         0.516171        0.635880
#               min       4.300000         4.900000        4.900000
#               25%       4.800000         5.600000        6.225000
# ...

# %%
ds[ds['Species']=='Iris-setosa'].describe().transpose()
# Out:
#                count    mean        std  min     25%   50%     75%   max
# Id              50.0  25.500  14.577380  1.0  13.250  25.5  37.750  50.0
# SepalLengthCm   50.0   5.006   0.352490  4.3   4.800   5.0   5.200   5.8
# SepalWidthCm    50.0   3.418   0.381024  2.3   3.125   3.4   3.675   4.4
# PetalLengthCm   50.0   1.464   0.173511  1.0   1.400   1.5   1.575   1.9
# PetalWidthCm    50.0   0.244   0.107210  0.1   0.200   0.2   0.300   0.6

# %%
ds[ds['Species']=='Iris-versicolor'].describe().transpose()
# Out:
#                count    mean        std   min     25%    50%    75%    max
# Id              50.0  75.500  14.577380  51.0  63.250  75.50  87.75  100.0
# SepalLengthCm   50.0   5.936   0.516171   4.9   5.600   5.90   6.30    7.0
# SepalWidthCm    50.0   2.770   0.313798   2.0   2.525   2.80   3.00    3.4
# PetalLengthCm   50.0   4.260   0.469911   3.0   4.000   4.35   4.60    5.1
# PetalWidthCm    50.0   1.326   0.197753   1.0   1.200   1.30   1.50    1.8

# %%
ds[ds['Species']=='Iris-virginica'].describe().transpose()
# Out:
#                count     mean        std    min      25%     50%      75%  \
# Id              50.0  125.500  14.577380  101.0  113.250  125.50  137.750
# SepalLengthCm   50.0    6.588   0.635880    4.9    6.225    6.50    6.900
# SepalWidthCm    50.0    2.974   0.322497    2.2    2.800    3.00    3.175
# PetalLengthCm   50.0    5.552   0.551895    4.5    5.100    5.55    5.875
# PetalWidthCm    50.0    2.026   0.274650    1.4    1.800    2.00    2.300
#
#                  max
# Id             150.0
# SepalLengthCm    7.9
# SepalWidthCm     3.8
# PetalLengthCm    6.9
# PetalWidthCm     2.5
